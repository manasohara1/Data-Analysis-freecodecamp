# %%
  import pandas as pd
  import numpy as np
  import sys

# %%
g7_pop=pd.Series({
    'India':120,
    'USA':100,
    'China':100,
    'Russia':90,
    'UK': 70
},name="Population of countries in millions")

# %%
g7_pop
# Out:
# India     120
# USA       100
# China     100
# Russia     90
# UK         70
# Name: Population of countries in millions, dtype: int64

# %%
g7_pop['India']
# Out:
# 120

# %%
g7_pop['UK']
# Out:
# 70

# %%
g7_pop.iloc[0] #same like index
# Out:
# 120

# %%
g7_pop.iloc[-1]
# Out:
# 70

# %%
g7_pop[['USA','UK']] #return another pd series
# Out:
# USA    100
# UK      70
# Name: Population of countries in millions, dtype: int64

# %%
g7_pop[[0,1]]
# Out:
# India    120
# USA      100
# Name: Population of countries in millions, dtype: int64

# %%
g7_pop['India':'Russia'] #gives proper slicing (Includes upper limit also in result)
# Out:
# India     120
# USA       100
# China     100
# Russia     90
# Name: Population of countries in millions, dtype: int64

# %%
g7_pop>=60
# Out:
# India     True
# USA       True
# China     True
# Russia    True
# UK        True
# Name: Population of countries in millions, dtype: bool

# %%
mask=g7_pop<100
g7_pop[mask]
# Out:
# Russia    90
# UK        70
# Name: Population of countries in millions, dtype: int64

# %%
g7_pop.mean()
# Out:
# 96.0

# %%
g7_pop.var()
# Out:
# 330.0

# %%
g7_pop.std()
# Out:
# 18.16590212458495

# %%
mask=g7_pop>g7_pop.mean()
g7_pop[mask]
# Out:
# India    120
# USA      100
# China    100
# Name: Population of countries in millions, dtype: int64

# %%
#operations
g7_pop*1_00_00_00
# Out:
# India     120000000
# USA       100000000
# China     100000000
# Russia     90000000
# UK         70000000
# Name: Population of countries in millions, dtype: int64

# %%
np.log(g7_pop)
# Out:
# India     4.787492
# USA       4.605170
# China     4.605170
# Russia    4.499810
# UK        4.248495
# Name: Population of countries in millions, dtype: float64

# %%
g7_pop[['China','India']].mean()
# Out:
# 110.0

# %%
g7_pop=pd.Series({
    'Canada': 35.467,
    'France': 63.951,
    'Germany': 80.94,
    'Italy': 60.665,
    'Japan': 127.061,
    'United Kingdom': 64.511,
    'United States': 318.523
}, name='G7 Population in millions')

# %%
g7_pop[(g7_pop>=60) & (g7_pop<=100)]
# Out:
# France            63.951
# Germany           80.940
# Italy             60.665
# United Kingdom    64.511
# Name: G7 Population in millions, dtype: float64

# %%
#modifying series
g7_pop['France']=69.69

# %%
g7_pop
# Out:
# Canada             35.467
# France             69.690
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in millions, dtype: float64
