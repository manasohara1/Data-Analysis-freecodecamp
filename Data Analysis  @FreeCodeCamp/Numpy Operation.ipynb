# %% [markdown]
# Brodcasting and Vectorised Operations

# %%
import numpy as np
import sys

# %%
a=np.arange(4)
a
# Out:
# array([0, 1, 2, 3])

# %%
a+10
#will not affect a existing array returns new array
# Out:
# array([10, 11, 12, 13])

# %%
a*10
# Out:
# array([ 0, 10, 20, 30])

# %%
a
# Out:
# array([0, 1, 2, 3])

# %%
a+=100
a
#will effect on a as we given = i.e a=a+100
# Out:
# array([300, 301, 302, 303])

# %%
l=[0,1,2,3]

# %%
[i*10 for i in l]
# Out:
# [0, 10, 20, 30]

# %%
b=np.arange(4)

# %%
a+b
# Out:
# array([100, 102, 104, 106])

# %%
a*b.dtype
# Out:
# array([dtype(('<i8', (100,))), dtype(('<i8', (101,))),
#        dtype(('<i8', (102,))), dtype(('<i8', (103,)))], dtype=object)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b
