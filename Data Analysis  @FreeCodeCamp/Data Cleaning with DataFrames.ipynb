# %%
import numpy as np
import pandas as pd
import sys

# %%
df = pd.DataFrame({
    'Column A': [1, np.nan, 30, np.nan],
    'Column B': [2, 8, 31, np.nan],
    'Column C': [np.nan, 9, 32, 100],
    'Column D': [5, 8, 34, 110],
})

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column A  2 non-null      float64
#  1   Column B  3 non-null      float64
#  2   Column C  3 non-null      float64
#  3   Column D  4 non-null      int64
# dtypes: float64(3), int64(1)
# memory usage: 256.0 bytes

# %%
df.isnull().sum()
# Out:
# Column A    2
# Column B    1
# Column C    1
# Column D    0
# dtype: int64

# %%
df.dropna()
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %%
df.dropna(axis=1)
# Out:
#    Column D
# 0         5
# 1         8
# 2        34
# 3       110

# %%
 df.dropna(how='all')
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(thresh=3,axis='columns') #3 values to be filled
# Out:
#    Column B  Column C  Column D
# 0       2.0       NaN         5
# 1       8.0       9.0         8
# 2      31.0      32.0        34
# 3       NaN     100.0       110

# %%
df.fillna(df.mean())
# Out:
#    Column A   Column B  Column C  Column D
# 0       1.0   2.000000      47.0         5
# 1      15.5   8.000000       9.0         8
# 2      30.0  31.000000      32.0        34
# 3      15.5  13.666667     100.0       110

# %%
s=pd.Series([1,2,3,np.nan,4,np.nan,8,np.nan,10])

# %%
s.fillna(method='ffill')
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     3.0
# 4     4.0
# 5     4.0
# 6     8.0
# 7     8.0
# 8    10.0
# dtype: float64

# %%
s.fillna(method='bfill')
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     4.0
# 5     8.0
# 6     8.0
# 7    10.0
# 8    10.0
# dtype: float64

# %%
s.dropna().count()
# Out:
# 6

# %%
  df = pd.DataFrame({
    'Sex': ['M', 'F', 'F', 'D', '?'],
    'Age': [29, 30, 24, 290, 25],
})
df
# Out:
#   Sex  Age
# 0   M   29
# 1   F   30
# 2   F   24
# 3   D  290
# 4   ?   25

# %%
df['Sex'].unique()
# Out:
# array(['M', 'F', 'D', '?'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# F    2
# D    1
# M    1
# ?    1
# Name: Sex, dtype: int64

# %%
df['Sex'].replace({'D':'M','?':'F'})
# Out:
# 0    M
# 1    F
# 2    F
# 3    M
# 4    F
# Name: Sex, dtype: object

# %%
df.replace({
    'Sex':{
        'D':'M',
        '?':'F'
    },
    'Age':{
        290:29
    }
})
# Out:
#   Sex  Age
# 0   M   29
# 1   F   30
# 2   F   24
# 3   M   29
# 4   F   25

# %%
df[df['Age']>100]
# Out:
#   Sex  Age
# 3   D  290

# %%
df.loc[df['Age']>100,'Age'] = df.loc[df['Age']>100,'Age']/10
df
# Out:
#   Sex   Age
# 0   M  29.0
# 1   F  30.0
# 2   F  24.0
# 3   D  29.0
# 4   ?  25.0
