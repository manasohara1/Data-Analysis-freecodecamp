# %%
import numpy as np
import pandas as pd

# %%
g7_population=pd.Series([10.12,30.43,60.78,90.43,80.02,120.10])

# %%
g7_population
# Out:
# 0     10.12
# 1     30.43
# 2     60.78
# 3     90.43
# 4     80.02
# 5    120.10
# dtype: float64

# %%
g7_population.name="G7 Countries Population in millions"
g7_population
# Out:
# 0     10.12
# 1     30.43
# 2     60.78
# 3     90.43
# 4     80.02
# 5    120.10
# Name: G7 Countries Population in millions, dtype: float64

# %%
g7_population.dtype
# Out:
# dtype('float64')

# %%
g7_population.values
# Out:
# array([ 10.12,  30.43,  60.78,  90.43,  80.02, 120.1 ])

# %%
type(g7_population.values)
# Out:
# numpy.ndarray

# %%
g7_population[0]
# Out:
# 10.12

# %%
g7_population[1]
# Out:
# 30.43

# %%
g7_population[0:3]
# Out:
# 0    10.12
# 1    30.43
# 2    60.78
# Name: G7 Countries Population in millions, dtype: float64

# %%
g7_population.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
g7_population.index=[
                     'UK','Ireland','Italy','USA','China','India'
]

# %%
g7_population
# Out:
# UK          10.12
# Ireland     30.43
# Italy       60.78
# USA         90.43
# China       80.02
# India      120.10
# Name: G7 Countries Population in millions, dtype: float64

# %%
pd.Series({
    'India':120,
    'USA':100,
    'China':100,
    'Russia':90,
    'UK': 70
},name="Population of countries in millions")
# Out:
# India     120
# USA       100
# China     100
# Russia     90
# UK         70
# Name: Population of countries in millions, dtype: int64
